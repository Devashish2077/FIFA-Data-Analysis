# %%
import pandas as pd
data_frame = pd.read_csv('FIFA23_official_data.csv')

# %%
data_frame.describe()
# Out:
#                   ID           Age       Overall     Potential       Special  \
# count   17660.000000  17660.000000  17660.000000  17660.000000  17660.000000
# mean   246319.424462     23.127746     63.369592     70.981200   1537.915855
# std     31487.892861      4.639821      8.036268      6.529836    285.893809
# min        16.000000     15.000000     43.000000     42.000000    749.000000
# 25%    240732.500000     20.000000     58.000000     67.000000   1387.000000
# 50%    257041.000000     22.000000     63.000000     71.000000   1548.000000
# 75%    263027.500000     26.000000     69.000000     75.000000   1727.000000
# max    271340.000000     54.000000     91.000000     95.000000   2312.000000
#
#        International Reputation     Weak Foot   Skill Moves    Kit Number
# count              17660.000000  17660.000000  17660.000000  17625.000000
# mean                   1.106285      2.900340      2.297169     25.037957
# ...

# %%
data_frame.head()
# Out:
#        ID             Name  Age  \
# 0  209658      L. Goretzka   27
# 1  212198  Bruno Fernandes   27
# 2  224334         M. Acuña   30
# 3  192985     K. De Bruyne   31
# 4  224232       N. Barella   25
#
#                                               Photo Nationality  \
# 0  https://cdn.sofifa.net/players/209/658/23_60.png     Germany
# 1  https://cdn.sofifa.net/players/212/198/23_60.png    Portugal
# 2  https://cdn.sofifa.net/players/224/334/23_60.png   Argentina
# 3  https://cdn.sofifa.net/players/192/985/23_60.png     Belgium
# 4  https://cdn.sofifa.net/players/224/232/23_60.png       Italy
#
#                                   Flag  Overall  Potential               Club  \
# 0  https://cdn.sofifa.net/flags/de.png       87         88  FC Bayern München
# 1  https://cdn.sofifa.net/flags/pt.png       86         87  Manchester United
# 2  https://cdn.sofifa.net/flags/ar.png       85         85         Sevilla FC
# ...

# %%
data_frame[data_frame["Overall"]>90].head()
# Out:
#          ID            Name  Age  \
# 3    192985    K. De Bruyne   31
# 41   188545  R. Lewandowski   33
# 56   158023        L. Messi   35
# 75   231747       K. Mbappé   23
# 124  165153      K. Benzema   34
#
#                                                 Photo Nationality  \
# 3    https://cdn.sofifa.net/players/192/985/23_60.png     Belgium
# 41   https://cdn.sofifa.net/players/188/545/23_60.png      Poland
# 56   https://cdn.sofifa.net/players/158/023/23_60.png   Argentina
# 75   https://cdn.sofifa.net/players/231/747/23_60.png      France
# 124  https://cdn.sofifa.net/players/165/153/23_60.png      France
#
#                                     Flag  Overall  Potential  \
# 3    https://cdn.sofifa.net/flags/be.png       91         91
# 41   https://cdn.sofifa.net/flags/pl.png       91         91
# 56   https://cdn.sofifa.net/flags/ar.png       91         91
# 75   https://cdn.sofifa.net/flags/fr.png       91         95
# ...

# %%
df1 = pd.DataFrame(data_frame, columns=['Name', 'Wage', 'Value'])

def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0
wage = df1['Wage'].replace('[\€]', '', regex=True).apply(value_to_float)
value = df1['Value'].replace('[\€]', '', regex=True).apply(value_to_float)

df1['Wage'] = wage
df1['Value'] = value

df1['difference'] = df1['Value'] - df1['Wage']
df1.sort_values('difference', ascending=False)
# Out:
#                 Name      Wage        Value   difference
# 75         K. Mbappé  230000.0  190500000.0  190270000.0
# 180       E. Haaland  220000.0  148000000.0  147780000.0
# 17        F. de Jong  230000.0  116500000.0  116270000.0
# 214            Pedri  115000.0  116000000.0  115885000.0
# 25          M. Salah  270000.0  115500000.0  115230000.0
# ...              ...       ...          ...          ...
# 8455        14 Índio   20000.0          0.0     -20000.0
# 2031   14 J. Zanetti   45000.0       1000.0     -44000.0
# 199          R. Kent   45000.0          0.0     -45000.0
# 1287     14 R. Giggs   60000.0       1000.0     -59000.0
# 997   Z. Ibrahimović   63000.0          0.0     -63000.0
#
# [17660 rows x 4 columns]

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x='Wage', y='Value', data=df1)
graph
# Out:
# <Axes: xlabel='Wage', ylabel='Value'>

# %%
from bokeh.plotting import figure,show
from bokeh.models import HoverTool

TOOLTIPS =HoverTool(tooltips=[
    ("index", "$index"),
    ("(Wage,Value)", "(@Wage, @Value)"),
    ("Name", "@Name")]
)

p = figure(title='FIFA 23', x_axis_label='Wage', y_axis_label='Value', width=700, height=700, tools=[HoverTool()])
p.circle('Wage','Value',scatter(size=10),source=df1)
show(p)
